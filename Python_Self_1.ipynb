# %%
#Practice from 1st lecture at Upgrad

# %% [markdown]
# #### About
#
# My name is **Prakhar Sinha** and i worked as a *Client Partner* at *Kings Research*

# %% [markdown]
# to know more about me [click here](https://www.linkedin.com/feed/)

# %%
print("Hello")
# Out:
# Hello

# %%
print("My name is Prakhar Sinha")
# Out:
# My name is Prakhar Sinha

# %%
print("Hello")
print("Good Morning guys")
print("I am back")
# Out:
# Hello
# Good Morning guys
# I am back

# %%
100+200
# Out:
# 300

# %%
200-100
# Out:
# 100

# %%
print(100+200)
# Out:
# 300

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
a-b
# Out:
# -10

# %%
c=10
C=100

# %%
C
# Out:
# 100

# %%
c
# Out:
# 10

# %% [markdown]
# ### **Write a program to define name, age and gender. Display them with a message**

# %%
name="Prakhar"
age="30"
gender="Male"

print("Your name is:",name)
print("Your age is:", age)
print("Your gender is:", gender)
# Out:
# Your name is: Prakhar
# Your age is: 30
# Your gender is: Male

# %%
name
# Out:
# 'Prakhar'

# %%
age
# Out:
# '30'

# %%
a=10
type(a)
# Out:
# int

# %%
b=21.5
type(b)
# Out:
# float

# %%
c=("Prakhar")
type(c)
# Out:
# str

# %%
d=True
type(d)
# Out:
# bool

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print("Type of name:",type(name))
# Out:
# Type of name: <class 'str'>

# %% [markdown]
# ####**Typecasting**

# %%
a=10
type(a)
# Out:
# int

# %%
a=float(10)
type(a)
# Out:
# float

# %%
a
# Out:
# 10.0

# %%
age="30"

print(age)
print(type(age))
# Out:
# 30
# <class 'str'>

# %%
age = float(age)
print(age)
print(type(age))
# Out:
# 30.0
# <class 'float'>

# %% [markdown]
# #### **Input Method**

# %%
name = input()
print(name)
# Out:
# Prakhar
# Prakhar

# %%
name = input("Please enter your name:")
print("Your name is:",name)
# Out:
# Please enter your name:Prakhar
# Your name is: Prakhar

# %%
name = input("Please enter your name:")
age = input("Please enter your age:")

print("User Name:",name)
print("User Age:",age)
# Out:
# Please enter your name:Prakhar
# Please enter your age:30
# User Name: Prakhar
# User Age: 30

# %% [markdown]
# **Example**

# %%
roll_no = input("Type your roll no here:")
score = input("Type your score here:")

print("Your Roll No is:",roll_no)
print("Your Score is:",score)
# Out:
# Type your roll no here:7
# Type your score here:50
# Your Roll No is: 7
# Your Score is: 50

# %%
age = input("Please enter your age:")
type(age)
# Out:
# Please enter your age:30
# str

# %%
age = int(input("Please enter your age:"))
type(age)
# Out:
# Please enter your age:30
# int

# %% [markdown]
# **Scenario Example**

# %%
num1 = input("Please enter a number:")
num2 = input("Please enter another number:")

print("Sum of two numbers is:",num1+num2)
# Out:
# Please enter a number:10
# Please enter another number:15
# Sum of two numbers is: 1015

# %%
num1 = int(input("Please enter a number:"))
num2 = int(input("Please enter another number:"))

print("Sum of these two numbers is:",num1+num2)
# Out:
# Please enter a number:10
# Please enter another number:20
# Sum of these two numbers is: 30

# %% [markdown]
# **Operators**

# %%
a = 10
b = 3

print("Addition:", a+b)
print("Multiplication:", a*b)
print("Subtraction:", a-b)
print("Division:", a/b)
print("Floor Division:", a//b)
print("Mod Division:", a%b)
print("Exponentiation:", a**b)
# Out:
# Addition: 13
# Multiplication: 30
# Subtraction: 7
# Division: 3.3333333333333335
# Floor Division: 3
# Mod Division: 1
# Exponentiation: 1000

# %%
e=2
print(e**3)
# Out:
#   File "/tmp/ipykernel_759/3860240156.py", line 2
#     print(e***3)
#              ^
# SyntaxError: invalid syntax

# %%
e=2
print(e**3)
# Out:
# 8

# %%
a
# Out:
# 10

# %%
a+12.75
# Out:
# 22.75

# %%
a+True
# Out:
# 11

# %%
True+True
# Out:
# 2

# %%
"TEST"+"test"
# Out:
# 'TESTtest'

# %%
"Test "*3
# Out:
# 'Test Test Test '

# %%
a=10
a +=20
print(a)
# Out:
# 30

# %%
a -=2
print(a)
# Out:
# 26

# %%
a +=2
print(a)
# Out:
# 28

# %% [markdown]
# **Comparison Operator**

# %%
a=10
b=20
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True
